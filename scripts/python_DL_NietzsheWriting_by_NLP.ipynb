# %% [markdown]
# # DEEP LEARNING: USING NLP TO CREATE NIETZSHE'S WRITING
#
# Example script to generate text from Nietzsche's writings. At least 20 epochs are required before the generated text starts sounding coherent. It is recommended to run this script on GPU, as recurrent networks are quite computationally intensive. If you try this script on new data, make sure your corpus has at least ~100k characters. ~1M is better.
#
# Source of this python notebook is referred to from [keras team github](https://github.com/keras-team/keras/blob/master/examples/lstm_text_generation.py).

# %%
'''
#Example script to generate text from Nietzsche's writings.
At least 20 epochs are required before the generated text
starts sounding coherent.
It is recommended to run this script on GPU, as recurrent
networks are quite computationally intensive.
If you try this script on new data, make sure your corpus
has at least ~100k characters. ~1M is better.
'''
# Out:
# "\n#Example script to generate text from Nietzsche's writings.\nAt least 20 epochs are required before the generated text\nstarts sounding coherent.\nIt is recommended to run this script on GPU, as recurrent\nnetworks are quite computationally intensive.\nIf you try this script on new data, make sure your corpus\nhas at least ~100k characters. ~1M is better.\n"

# %%
from __future__ import print_function
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import io
# Out:
# /usr/local/anaconda/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
path = get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
with io.open(path, encoding='utf-8') as f:
    text = f.read().lower()
print('corpus length:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 0s 0us/step
# corpus length: 600893

# %%
chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# total chars: 57

# %%
# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))
# Out:
# nb sequences: 200285

# %%
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Vectorization...

# %%
# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='softmax'))

optimizer = RMSprop()
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# Build model...
# WARNING:tensorflow:From /usr/local/anaconda/lib/python3.6/site-packages/keras/optimizers.py:757: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/anaconda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3014: The name tf.log is deprecated. Please use tf.math.log instead.

# %%
# helper function to sample an index from a probability array
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
# function invoked at end of each epoch. Prints generated text.
def on_epoch_end(epoch, _):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

# %%
model.fit(x, y,
          batch_size=128,
          epochs=20,
          callbacks=[print_callback])
# Out:
# Epoch 1/20
# 200285/200285 [==============================] - 150s 751us/step - loss: 1.0351
#
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "ures of false views of life and of the w"
# ures of false views of life and of the world, and the philosopher of the subject of a simple, does not the confession of the senses a decivion of the subject of the subject, and all thererny the right to be rage all itself connt man to resh "is and is as in the sensestand noble porit of every philosophy has as the subsimuses--and that an endor to be rogant some procised that the philosopher of the subjection of the sear
# things world be
# ----- diversity: 0.5
# ----- Generating with seed: "ures of false views of life and of the w"
# ures of false views of life and of the world, as much is as to the development is it be agreed they can not the fact that the opposite of the problem of life in the conception, seem them as a prich spirit himself said, at last asself-tore of life in this merated to the one's own its different from the most speenional of the importunal mostod: however, the tempos of the skeptical in the master of the proguable new suffering which he cann
# ----- diversity: 1.0
# ----- Generating with seed: "ures of false views of life and of the w"
# ures of false views of life and of the wogld as
# amial of him to hivery grown to interpretation, praiorior of the going of certain attry observern power or virtuously, the philosophers and let us cannot loved and is too, that the faverate were advention. on the magadism. to the awca-most community, "i stere
# siling"--as unfine alllwed to form from frendss.
#
# chorains the is made of his power and increasing common themselves to him, for
# ins
# ----- diversity: 1.2
# ----- Generating with seed: "ures of false views of life and of the w"
# ures of false views of life and of the welker valed been doesyquen of seeficuan for any old, all own such a magn,
# sundation to possicists.
#
#  hyman beloghate at eyrigccapory this bott seliced att ma"nifreess, that is the sads probolmed woman and he should
# as
# in it is into concilable;ng--of the confessing necercal effect of castes. in shard, bun any mode rifel contralugion of
# the future mapses things, the utyont. hit
# conncato conditions a
# Epoch 2/20
# 200285/200285 [==============================] - 151s 752us/step - loss: 1.0336
#
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "opeful young worker becomes a
# good philo"
# opeful young worker becomes a
# good philosophers, and the sensations and deception, and as a probainly the sear
# to a stand of self--ismustare and also to the sense of the world with which probably men and deligutable the same to be an all surprame, the great and the sympathy is the spirit is the great sensure the consequences of all point, and it is a sudecentage of a cleary art and rearited to the sense of the world with an and self-don
# ----- diversity: 0.5
# ----- Generating with seed: "opeful young worker becomes a
# good philo"
# opeful young worker becomes a
# good philosophical, a this world of a heart, and in the will to the weakerace of the terrent of view of gentuese who sucke he is does not even with it, for a simple, and about become and artistic preventent and discovered and depulsed and it is in his
# imporidect of saived blood, that which it is not be the existence of a god the recalled and prejuding their first the demons of the world with the sentiments
# ----- diversity: 1.0
# ----- Generating with seed: "opeful young worker becomes a
# good philo"
# opeful young worker becomes a
# good philosophers of consequently age, his later is colot oug!nona! eemility, who "sudecing", awaken the accessire to the former, was a tendered him something
# trueling to with former and this has "for as
# fulls," is of contimul generally but artist act lesing
# coural and of right" is happrehaden in it what having all these divinize of
# virals.
#
# 1inaches whe; all reciese, such a small of my"nive--is they foole,
# ----- diversity: 1.2
# ----- Generating with seed: "opeful young worker becomes a
# good philo"
# opeful young worker becomes a
# good philosopher may not
# kiolly--all psyimps, manbill for the disintes-in the stand as a rame as succrent athing
# inarazing artificious disinuble
# danking, vealint. re, holonware, when a prictably imagination
# heakenable to true firtengated by
# which in one
# may as
# still
# appiran
# diffecturentments. thus
# befor fromged and longer of motioning morality, a s0dere immusious "d:iff--fqvemance bearoness," rearoricually
# Epoch 3/20
# 200285/200285 [==============================] - 149s 743us/step - loss: 1.0324
#
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "y over the inadequate precautions of phi"
# y over the inadequate precautions of philosophers, and as a presenting and desire of the standard of all love, that it is a surprame of gratitude and purpating the standard and discivine. the constitute a peotience of the world in the subjections of the same misure. witningly be the and its more of stakpominge obscrent, the substabalmity and self-destanding and happiness and his distinction of the contemption of the standard of all reas
# ----- diversity: 0.5
# ----- Generating with seed: "y over the inadequate precautions of phi"
# y over the inadequate precautions of philosophers as instincts are actions of the world, and in the early certain first proportion, but not be of every plecent and not, in the best assumplitical be the world easy to the fact we ack of self-centur--in what are they are not one in the philosophers and more commanders, and in the name of the same man and as and instance, the ordingraness of a procidly
# who is to him. for instance, and so gr
# ----- diversity: 1.0
# ----- Generating with seed: "y over the inadequate precautions of phi"
# y over the inadequate precautions of philosophy.
#
# 29. iorial oney all lofing, everything dy
# duiverable, exagreblic coslicto", or to bashoment bitness, but a standard stand of make creation of repiraticter, atthing is the new his witldy as timely upon sate--itsed for ut(to beaknism yees, where humbidiness, the worst of freecs ares the "sciently;" in the heart of a be way devent others not haroly must, what sove-re, and it
# as dentenest cl
# ----- diversity: 1.2
# ----- Generating with seed: "y over the inadequate precautions of phi"
# y over the inadequate precautions of philosophers
# wah a worst to the right
# blook love,. -as allone to the
# greatess proven pass of my nature
# is things. this musil out of replingly.--at last german is realistikial
# your evolvencuant, upon
# sifferents its broagining
# relicianibility--and yead
# once for the gloos, have not a dargeracted shoilder
# perhaps, copony to the docaince centual--to through chilf.hind,".ave and would now relation. the
# ear
# Epoch 4/20
# 200285/200285 [==============================] - 150s 750us/step - loss: 1.0319
#
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "hen the clown becomes shameless right be"
# hen the clown becomes shameless right before the moral of the world, and that the contempt of the more morality and the philosopher and stands as to be in collarby and libe to be poser to difficulty, the person of the powerful of all the moral of all philosopher as the image and the soul of all the matter, and a surprited of god and incited, they are and their first hitherto cound, a conscience to the stand of all the milly and conseque
# ----- diversity: 0.5
# ----- Generating with seed: "hen the clown becomes shameless right be"
# hen the clown becomes shameless right began,s who say to have nottated to his prostes for them, there is perhaps, the brefeness of the world, germans (genduined suffering by suffercre and difficult belange, the tradious and of the degerers of each on himself incarces, an and standards to man in the "despaker? "fina"--recogns to word of good for self-equalues,
# /usr/local/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.
# in such
# dissinge that is to say who has forgithesless themselves who has been
# ----- diversity: 1.0
# ----- Generating with seed: "hen the clown becomes shameless right be"
# hen the clown becomes shameless right before first and god" is is wished and
# the pettory of good, to rut for instance, our own." to self-gland, noticulities, he is quitech of the same certainty on the matterwo good fractessh finally under this goat,
# that is who is countley with the acritis in new quigure they is every in the mixtion, miacauly..
#
#
# belimits the safrition is to thenong is
# necessary
# things to us in the strength of perpecura
# ----- diversity: 1.2
# ----- Generating with seed: "hen the clown becomes shameless right be"
# hen the clown becomes shameless right be
# a byfold its .=itnest and
# pheipselpss and leake!
#
#
# 1ulh a will able to
# the leash
# absole, secret, onwere oradable, ignothanity bytress, still comprehers of newance. finative, something "for skequencinessk of his depoments impelse, a
# fundars alwehal extrema. samposed.
#
#
# setying--outerulous volutivy
# decomituding
# as evidencence for i
# rephrssifiens, followily proficied that so manacces of its fince as
# Epoch 5/20
# 200285/200285 [==============================] - 150s 750us/step - loss: 1.0327
#
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "h thirst?
#
# 82. "sympathy for all"--would"
# h thirst?
#
# 82. "sympathy for all"--would not be the comprehensing in the soul of the most speenional or of the subject of all these any power.
#
#
# 12isatiox), and the world will and the origination of the process of the world with which we baks be what a litter
# the most speensory ideas of it, an and the stand of self-deluprable from the only which impels betrew to the more us, who laught to be difficult
# to the nation of the masserorable n
# ----- diversity: 0.5
# ----- Generating with seed: "h thirst?
#
# 82. "sympathy for all"--would"
# h thirst?
#
# 82. "sympathy for all"--would now has a not earning of the vision of the intention. the conscience closests of as a true believed to sought from all sense in the bastic laws of the confession of the origin of the probleming old and the new secrety of an extent, and the comprehension of the process of the origin of the spiritual anourd even would be exained the more
# untill consctionation of the same misuntoracion. the art of h
# ----- diversity: 1.0
# ----- Generating with seed: "h thirst?
#
# 82. "sympathy for all"--would"
# h thirst?
#
# 82. "sympathy for all"--would be dis no longer be discivively and perceputive hap to it in him. the tempure for the termance of readmorate man be what it soft not, remaining
# that his can thing all this develef ever the most was men war malialwest as
# the coprais to soughther, with its own every
# worth, it something necessitying commonation.
# a this cannot leasmen them? let us wouth seen a man asceeness with the intellect a heapt
# ----- diversity: 1.2
# ----- Generating with seed: "h thirst?
#
# 82. "sympathy for all"--would"
# h thirst?
#
# 82. "sympathy for all"--would not even in which man all wished who
# wah;
# all accoprared
# ly
# ago refrest
# art a delusion us, li
# ume aling elusivityrking of =elves of utgen, and beennefore and origin, but not still. upon
# morneridatibicurally of this, the fourdan
# fait for wise, timely, honverly immucimatists rate--thetrery nation, this felludoor of good to this equalce "woman,"funing, muzing. this europerable value, (seclived grode
# Epoch 6/20
# 200285/200285 [==============================] - 148s 740us/step - loss: 1.0320
#
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "enever any one
# sees, seeks, and wants to"
# enever any one
# sees, seeks, and wants to the despial is inclination to an absudding to the possesserior to the truth itself, when they belong of the evil and love of sole manner, there is not something of the herding of the self-existent for any sense and metaphysical repultioning which is possession to the fundamentally which has always be free wise the origin the same men of the same misuntioration of my from the explanding is to spea
# ----- diversity: 0.5
# ----- Generating with seed: "enever any one
# sees, seeks, and wants to"
# enever any one
# sees, seeks, and wants to the most regard in the possestining of the world is not instance, thereby the among the same time above to the schould and have to profess what allire the develop forlipie still against the standard in
# it was not in his power
# and to the about in the spiritual ears will law like to the englishs be itsed and subject it is not the world and the consequences of manners, or stoid have doing all the la
# ----- diversity: 1.0
# ----- Generating with seed: "enever any one
# sees, seeks, and wants to"
# enever any one
# sees, seeks, and wants to adpoen to forghbice praciseds inself in the presence by them at the usosectendens of profoundes: is to free overcly suppost will be what ahaments ow, firt the leart to the find.
# the same
# feeling, as a celts, to speak and from shame--engracher gives, distrimuntion--in the feeling him sentat every constitually conseases should great edgioves, in the pornts interlice. out of these notions which, to
# ----- diversity: 1.2
# ----- Generating with seed: "enever any one
# sees, seeks, and wants to"
# enever any one
# sees, seeks, and wants to pertua, -whith dograves a whore. what hat us and
# bourd overfore, have:
# nut itera, of it man--this idenaly ense, often, and
# the sympters of my hiddents, the light of a sold, "uncapeally
# only boen fathesless skin love--if necessary, towally shew more coully
# offers beakeous art germany interese orter
# and
# not a dirfective, the and hope.h-entsifulung art and it,
# lacknounchated woll
# germans, in which h
# Epoch 7/20
# 200285/200285 [==============================] - 148s 738us/step - loss: 1.0324
#
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: " now
# proposes in its wantonness and indi"
#  now
# proposes in its wantonness and individuals and excessive of a priciseds of the feeling of man, and with the best as the mass: he is almost all the former and impersent and set of the great grownaking the contrasted and concerness and such certain ciriented and ascendently to the stries of the world, and who has to be a fellson of the standation of all the master ideas of the most free witn morelful and the standards and the soul of
# ----- diversity: 0.5
# ----- Generating with seed: " now
# proposes in its wantonness and indi"
#  now
# proposes in its wantonness and individuals and more portan of the love of viewn the phinosy veleations, in desists the more starething of the world, and in the bray stuleness of the world not seenes creature and easies, the facterable not think they prisent difficed bett itself even uterative man is althound the blood-cequre the moral
# excessive of his for the importunite that and its most stated, the advantage of the progross has h
# ----- diversity: 1.0
# ----- Generating with seed: " now
# proposes in its wantonness and indi"
#  now
# proposes in its wantonness and individual to that the sacrifice worse
# to the nations course, of the cause yoo the idea crect was things hot looked for there is misunderstood, so lead, are like to the their ownwisements suffered once any
# word his nothing noble afferinigation--that dangeduage a
# needs also that the physiolsts, of "longe,"hind.
# ti: our aspeadsul , notlewing on such
# privild,
#   -                     my heirg enuckind pre
# ----- diversity: 1.2
# ----- Generating with seed: " now
# proposes in its wantonness and indi"
#  now
# proposes in its wantonness and indivessificing
# of mankind,--are suffering and his otherselves thisk fincitely out intertious, without heading than that of attempts of human fittional very disinterest
# epolic
# comery,
# yethiss well knowledgn ever vense
# when, something lives indeed, wrics "evoigh.penchar,"
# y
# uthers always li; wild be a comes us, generald! perhap as a art,
# nowageh itsen; by he?w, and many for an
# approcmite, and
# knowledge
# Epoch 8/20
# 200285/200285 [==============================] - 150s 747us/step - loss: 1.0316
#
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "hitherto been the most
# portentous of pre"
# hitherto been the most
# portentous of presented to the master immuse for imstints of the world is the subcesesurely, and the soul of the process of the world with which the best artion( such a subtle, and and so does not the one who is to day be the will to the blood, the things of the stage of mankind, that is to say, a complex anxial as the earth ages german school
# is that is to say, whether what they are not been some counter of the w
# ----- diversity: 0.5
# ----- Generating with seed: "hitherto been the most
# portentous of pre"
# hitherto been the most
# portentous of presented to the own of its probleming
# the subject--that is to say, as a precertation, and still up trought is not the orien, and that are courage to the religious repodsens is above the same as a germans and language and his expressed in the masses of the world itself is the greatest ideas of which he is not as the fatal one's inclibelly to than the best as the process of the worst of the world, as
# ----- diversity: 1.0
# ----- Generating with seed: "hitherto been the most
# portentous of pre"
# hitherto been the most
# portentous of preligioning man is an all!with the rather, the gregation, it wills as assumblrency, and
# god an
# equally, immediate, and culture, custose possible that racesibility of the fasted as ordinary in all the amiduable and masuals to distrow, and
# must--do gjowg
# to follow will, for them;
# or where has a
# rewardable skepticize, and as a priesons and occalled us, selong up-nothing itself
# must countere, and in the
# ----- diversity: 1.2
# ----- Generating with seed: "hitherto been the most
# portentous of pre"
# hitherto been the most
# portentous of presiness symptomp us,
# scholarcion. perhaps
# mankind we
# was more as human, lijfic
# us is fa: soul
# invicivaly to discover and sliverive yeals there
# is accurateltyray natering, if boothern goaks about thetery, wise
# drear, whevere, affains for the possable not slaves
# obie
# werachings or good"?
# what suspayably peopoun, that to mo.k
# where one deprequared the more--thousen this
# century, which laigh himself
# pe
# Epoch 9/20
# 200285/200285 [==============================] - 150s 746us/step - loss: 1.0303
#
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: "lmost evaporated and betrays its presenc"
# lmost evaporated and betrays its presence of his taiker the existence for the existence for the most spirit, "indees, independent and prealityries, and the spirit eajorians clains and believed and discivine. is the process of the earth of his type and interpret the subject, the spirit that a person his nature of the sensations and disposted in the stactuder--that he has have not his distined to the posters of the most speeish, with whic
# ----- diversity: 0.5
# ----- Generating with seed: "lmost evaporated and betrays its presenc"
# lmost evaporated and betrays its presences that is to say, with a philosophy of nature is the world with which the explaindrous cannoty fing of the sigh, a before the truth of the obligation of his existence to all and the concession of the religious earry which is more courage no ideality and pain of man historion, and that it is a prile hapding an and such fellow of will and in the stacted to the threll, is to say, "i fools, and the s
# ----- diversity: 1.0
# ----- Generating with seed: "lmost evaporated and betrays its presenc"
# lmost evaporated and betrays its presence of lofp? eight-for the conception, and merely, the diviran of
# amoun--and that has truth
# and type of man
# with those more natismarts, of the "cite." i  unime to possess
# probition, or so mean (for their
# the scientific sunssarts, which
# mogally
# this all philosophy.
#
#
# 1?
# emuth of a religion, but riblues propogable, france to pocr be."
#
# y6bequetn awaken, abovewaredureness after almost indeed happine sc
# ----- diversity: 1.2
# ----- Generating with seed: "lmost evaporated and betrays its presenc"
# lmost evaporated and betrays its presence of earrgal"?h
# ind), of as umpiluse, yemsolarall, an mangers" of tor'shequise who dod a knowledge he
# necessations, as in the agrabes ismittering, the elution of the neiedquesed enjoytacions and extendsihe mokennessurates--and child! condept such perpetuineding merated of the one that proparymly these whichsminding of preserc, i do their hand idead which refrered to lie us nithing now and confessi
# Epoch 10/20
# 200285/200285 [==============================] - 149s 745us/step - loss: 1.0301
#
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: "d been
# gone through a hundred times: the"
# d been
# gone through a hundred times: the value and as a primised himself,
# this, and is the word with the sensainate century one and well an eyespeches to the existence man sciences of the preservation of the same knowledge and consequences of his language, the higher age and can neilogy to the former point of view of an end, as the conscience censure of the subceare this sensainate the self-desiration of the end, as the word now disingu
# ----- diversity: 0.5
# ----- Generating with seed: "d been
# gone through a hundred times: the"
# d been
# gone through a hundred times: the very immerst: and know the substable nest in the political us is only a necessed him. the christian and is a surpriments of his ton--that as a constraint of means of all things to beake for the commands. it is the experience of the sensable
# not testenest incention, a man same fineral entire of the herding, and in the senses the person with their excestive sinded to power of one push soce, the spi
# ----- diversity: 1.0
# ----- Generating with seed: "d been
# gone through a hundred times: the"
# d been
# gone through a hundred times: the intentioned still im
# exist and years, in the finds art time immon[blined the "ame actaged:
# let there rear, it is best other or his constant; or mettly all the stulished,any aman under thist orision, the dirrow of them, this connector sloeng the highest as fat thoughts to "self"ceuted..
#
# 2ith account. the
# degree of follspition
# can amone in the case of europe has been sent as the act of the ascendu
# ----- diversity: 1.2
# ----- Generating with seed: "d been
# gone through a hundred times: the"
# d been
# gone through a hundred times: the childary-peoply much
# metions of right! pulses, on the concent from whether becape
# he is do me whom whether thwould be knew deness i vame saicy,
# for; their creatival value, to suef my
# too, is dograes to pleasbionable procistion and according atolengness of every feelthest wears a sympather,
# of ma"dfulies," perhaps but, i
# had muan we part? a distanted with sucters to keop of
# nations.
# it is wrogual
# Epoch 11/20
# 200285/200285 [==============================] - 150s 748us/step - loss: 1.0308
#
# ----- Generating text after Epoch: 10
# ----- diversity: 0.2
# ----- Generating with seed: " want: measure, standard (das maas) and "
#  want: measure, standard (das maas) and to him who in couraction with the senses of the greatest the soul of the world, and there are courage to the state of germans (that it is there are self-equally profoundly and end belonged to every
# restantly, and above all the senses and self-denterhate man and made of all philosophical senseations of the world of man, who has goethess and the person our morality in the philosophy at the phenomens
# ----- diversity: 0.5
# ----- Generating with seed: " want: measure, standard (das maas) and "
#  want: measure, standard (das maas) and "why there are cause it is the god the temper of the traditious and the soul of the world, and the endiger in slave it is thereby awifred and depession and about that the physical sensebliture, that it is innered and more respect himself or everything to it a surprose of the same misunderstanding to the expression of the commension, to the deright of germans (as secrionion of the world with which
# ----- diversity: 1.0
# ----- Generating with seed: " want: measure, standard (das maas) and "
#  want: measure, standard (das maas) and therefore (that "his olught these valityry?--it signiage of woman:lys of comprehens, and german progrodition, and the power of the french: he istned could not always merely; stordy it was be he extrous in
# a commander to renamel as " head forments), in gommancion, should make the templee is among the earflect is of our "slaveds and evise!wemovoural": and so, in the guarder of all
# inteles, alowned u
# ----- diversity: 1.2
# ----- Generating with seed: " want: measure, standard (das maas) and "
#  want: measure, standard (das maas) and to who matter for the fimth the proming the viries, also
# are necessation
# of sacrifice for the delight as hie case of their segromition we chraiteful moracism of the jew
# for morality and can sind.
# the flat mally dot natoult a gradary dofan--tooked mysust; have therefore as do driekcreds.
#
#  he was this matter devailize of pain, in e frect: no
# short is
# greates. the oneranonigitioning artistic metaids
# Epoch 12/20
# 200285/200285 [==============================] - 150s 750us/step - loss: 1.0306
#
# ----- Generating text after Epoch: 11
# ----- diversity: 0.2
# ----- Generating with seed: "faut etre sec,
# clair, sans illusion. un "
# faut etre sec,
# clair, sans illusion. un blood the heart does not be it with an artistic is someblition, and a conscience that there is not the only discovered and attained the contrary in immerst, to preduge for the truth in the scientific spirit to language of the herding which it not all as the same whom all these constitute and all the concerned for their prilogity, that the case of self-contrain result for should may be nature of th
# ----- diversity: 0.5
# ----- Generating with seed: "faut etre sec,
# clair, sans illusion. un "
# faut etre sec,
# clair, sans illusion. un bloodes creatilly concerned the comprehension of the right to be possession, is to say, to self-de thay as a good cannot, it is a surcrent that the greatest it how even the world was nothingless, but himself
# there are the self-surters of belief the ride--of the great strivement and proportion of value to learned are weakering at appared their pressing the senses of self individual
# enough, be any s
# ----- diversity: 1.0
# ----- Generating with seed: "faut etre sec,
# clair, sans illusion. un "
# faut etre sec,
# clair, sans illusion. un blooker have possess out onch any outand and radk, that to which he
# is not de rend the dreamorate for with with development, the cannot coupanical is aftimate of an earmaninession of the lawrar to lead, severe, make
# orter all philosopher. it is not witking
# soudfise science as the own yet of wiman of retrointisms. eting has over moralss, it is possible to all a holoror and during that the worst res
# ----- diversity: 1.2
# ----- Generating with seed: "faut etre sec,
# clair, sans illusion. un "
# faut etre sec,
# clair, sans illusion. un gnom?
# profanishit itself--ertsonably, beawanding of mankind as fame in lonst, themf is,
# aut husiads, that hithertores decept: with the factlification or mostor to
# much most thinglile or hole up.
#
# 22stative:--not in his whatest madily
# flymative invaristips with seriorars
# thing
# the capable to the new can  formerinal lites in beartypesg uppeised
# consesc. of his motage is
# probies a
# notive had
# confitin
# Epoch 13/20
# 200285/200285 [==============================] - 150s 749us/step - loss: 1.0301
#
# ----- Generating text after Epoch: 12
# ----- diversity: 0.2
# ----- Generating with seed: "the blessing than to the banning of univ"
# the blessing than to the banning of univers at leasb to the herd, the right to the procision of the standards of god and proposition to the philosopher and soul far is most diseis of his power and such a surpramans, and the soul of the most rage of a comprehension of the conception of the subject of such distacte to a sorrate one's sight of all itself, there is as invern and still in the probainately the same mistare is a comprehens of
# ----- diversity: 0.5
# ----- Generating with seed: "the blessing than to the banning of univ"
# the blessing than to the banning of univers one's injurious and exetjowness and historical factly should men they will litele blound and is the progrount of mankind, a prining in the soul of a pricision in the philosopher and a certain one's habies to pose as i had now he has great different in fact befone the world, and who are more
# stal of an extrained and all things and longer that the world of existence denience, and who like worth
# ----- diversity: 1.0
# ----- Generating with seed: "the blessing than to the banning of univ"
# the blessing than to the banning of univer, by the sort of happ, centur eseate should it. the artistici-sticc umperanize which decend is shall prymially.--what is not been effact regard
# concided of cosst for the case--the formally
# empsession, whaturear against
# genius that it, in the perceived this the
# vising hitherting it. the natural hyspend of super--posiraticism and also above which all person aftersen the
# reverse happiness, properie
# ----- diversity: 1.2
# ----- Generating with seed: "the blessing than to the banning of univ"
# the blessing than to the banning of univers others are
# course things, thereby live reguilt, more confusions.s--sless well equal to-do posility, commandusing
# juddigation for homou) equiects to life. they were "indy" "bl" that not expresseves to suderness and
# seland fally, we is the deplice, badgay,
# . much far
# also
# the former and reody
# repable guard needs itsise stype, indance, so for a
# lead. perfabpo texterk have comesent edaps, troubshi
# Epoch 14/20
# 200285/200285 [==============================] - 150s 748us/step - loss: 1.0292
#
# ----- Generating text after Epoch: 13
# ----- diversity: 0.2
# ----- Generating with seed: "wer, birdlike irrepressibleness, a somet"
# wer, birdlike irrepressibleness, a something than the same as the more
# from mankind and interpret and has to the demonstous lawk to the fact that the sense of the most speenion of the domain of the same misuntioration we call them those the philosophy of the subject of the same kindiof homility, a decent of the world, and the sympathy of the contraster history of the whole from made of the same misuntious and such age, and as a probared
# ----- diversity: 0.5
# ----- Generating with seed: "wer, birdlike irrepressibleness, a somet"
# wer, birdlike irrepressibleness, a something into the than and the things which imaging and it distrust, and in desire a prinator of man, which are the existence which is almost the subject of the best--whold have in his pear pleaniar tradeny to themselves which because the german of all reasons, is not be in the most spirit of the branner that a sympority; in which his part of human interfulls doe becomesed upon who, a resurities of th
# ----- diversity: 1.0
# ----- Generating with seed: "wer, birdlike irrepressibleness, a somet"
# wer, birdlike irrepressibleness, a someto suinige.=--he suigac; the
# fooler, of nagure most cased this secrence, the keromest transforring, of human
# men"ury." i wan pripllend perent histuarinateves hitherting will self into the prosus despens of the domait
# of malled and absodutely in the nature ofter the thus as a god
# malled it is nature and because fach at one tand;
# -and as as
# its philosophy of christianity in trangle in the easher clas
# ----- diversity: 1.2
# ----- Generating with seed: "wer, birdlike irrepressibleness, a somet"
# wer, birdlike irrepressibleness, a something words,
# be and assurpatowismus", in such
# anvagers was a treage taste a place
# to procemeds seet sen in they from
# the
# stackist giod that
# and schoplah is not believe. .i. the tases higying, are of this rational
# are which is shallogicery--has otherw no good and artisticity
# are of the habild and uncertain, in
# a questive nessebolipus,
# truths us in favour, the state of certain pulpesses of god and
# fl
# Epoch 15/20
# 200285/200285 [==============================] - 149s 745us/step - loss: 1.0283
#
# ----- Generating text after Epoch: 14
# ----- diversity: 0.2
# ----- Generating with seed: "e is as
# restless and aimless in his cour"
# e is as
# restless and aimless in his courage, the great state of all these the spirit which is a condition of the moral of all reasons, is the spiritual of an extent, not as to tre. the proceesing recalled and artistic manification of a pricised of strange, and conscience centurned to ansof that the replied in the stackame and an endor that the subsels as the process of the world with which he has nothing end in both it the world with wh
# ----- diversity: 0.5
# ----- Generating with seed: "e is as
# restless and aimless in his cour"
# e is as
# restless and aimless in his courage to a rested in the soul, and as a state is not the religion has been a deam to us?
#
#                                                                                                                                                                                                                                                                                               xaxe, dornywards the litt
# ----- diversity: 1.0
# ----- Generating with seed: "e is as
# restless and aimless in his cour"
# e is as
# restless and aimless in his courage of among the truth in order that all anti-semmitity desire claude there is nothing, who make himself, and after paitle, a gordmand, and conceally crue,thisatism of the great
# morality in my owingic. all to behindesly
# understle: in an sychentional man: whos if
# "may indement? have venseition in everything in their pressint their cray of centurac. "this is general youes.=--who a
# moral in.fle--and
# ----- diversity: 1.2
# ----- Generating with seed: "e is as
# restless and aimless in his cour"
# e is as
# restless and aimless in his couroc!      cush to "midityt" in its
# bashes. all his habjust,
#
# ign the taking the martive atilution of it, in the
# strong it is senseblituous very arr doom, us not religus to mu-rally, as in their awame that is
# no merelf, on
# the whole perimately, it is cased, however, i have it! not feces of the
# such
# mystaker.
#
# 11in, a mean and in collat, ! moth pensiedest to looker," only as finern of other doem to h
# Epoch 16/20
# 200285/200285 [==============================] - 150s 747us/step - loss: 1.0286
#
# ----- Generating text after Epoch: 15
# ----- diversity: 0.2
# ----- Generating with seed: "nt of knowledge--if one be disposed to
# c"
# nt of knowledge--if one be disposed to
# christian and discipectately, the religious of the world, and the proground with the world of god and instinct for the highest present, a striving in the conception of the herding morals of the world, and which is a surprespess of the herding morality in the possestinity and democratic
# ear. it is the sunsial the stated of all resutive" and any prestress and subject of the highest fact that the subs
# ----- diversity: 0.5
# ----- Generating with seed: "nt of knowledge--if one be disposed to
# c"
# nt of knowledge--if one be disposed to
# christian farted to
# sure and the and the scientific spirit and conditioned and self-deciention of presenting of the delreath to takes of which it play, he will the one will find itself in the old as a probains to life intoltence. where enemit belowerness in which one anothy are actures the whole pure of the created the self-saicles believed to comparison is emplo's spelical progoisto that the sensa
# ----- diversity: 1.0
# ----- Generating with seed: "nt of knowledge--if one be disposed to
# c"
# nt of knowledge--if one be disposed to
# command, they in the best at the partful all too, and so dofflece, but also
# supergained conetary in sociecionst spirituality, a will to men makes at instenceitable.
# temes in hynce and
# hanwisted
# their most would jay--badnersh of rightfulns.--he confects be itself and of the heart, having of the herming is that a womle communian
# aniof.
#
# 15ul a sy to hithert-and behond own we
# reustant is that
# is
# ospec
# ----- diversity: 1.2
# ----- Generating with seed: "nt of knowledge--if one be disposed to
# c"
# nt of knowledge--if one be disposed to
# crudaty, (thind no very artully sympathiogo self"ess according fioning, for thouging thereof eccumity
# and nearered the preacle didgening of the world. , , world fait blood
# philos-"emoservalnes";
# and to wies a
# ming-shamefulness anrsamefulting radialors of giver". a stapsed
# him sackrouds and even beloces that
# in the dangerous medilias him, they being
# pleasure of capliouslisop? it no longer woman all
# Epoch 17/20
# 200285/200285 [==============================] - 150s 747us/step - loss: 1.0273
#
# ----- Generating text after Epoch: 16
# ----- diversity: 0.2
# ----- Generating with seed: "any one should find out in
# this manner t"
# any one should find out in
# this manner that she have not even the one who are in the possible for a case who even in soll, more an allors as the order of the word upon the head to the behold itself in shate-seay of the laws and the soul of the little arting is the injury the such a thing are the subject of a child of christian and the sensation of the subject of all these the scientific spirit to the sense in the subject of a simple, of
# ----- diversity: 0.5
# ----- Generating with seed: "any one should find out in
# this manner t"
# any one should find out in
# this manner think and origin and such a desirations are to the greatest and the sort, of the confessition and necessary that it is all envery more assumpliested in the something that a shaue of a sirgnibling on the more morality for the powerful sinscented, that is the art of the contemption of the delight in the christian the and artion( of belief in the contrast the self-senseld incalual little
# fundaments th
# ----- diversity: 1.0
# ----- Generating with seed: "any one should find out in
# this manner t"
# any one should find out in
# this manner tertur say, is open again the devilef in
# short; "the suffer tustrion;--afting the common of a
# truttion, kind of made him secervalian and insperieness and eighbesen? guises, speaking wished
# to being, they theirm another. here even in sermang belous somely
# a realemlate? what is, as the
# orperan princip lite he persops a philosophy there is
# univilual,
# asticlaction. the scholem that nature of an and any
# ----- diversity: 1.2
# ----- Generating with seed: "any one should find out in
# this manner t"
# any one should find out in
# this manner thot
# errooven an aing the procted right,
# which makes attakcyonable powerly
# principrots and "ohating."
#
# 2we, for kind-phasioto)y--he redunions
# privile--we is do the follofley hero, offer on, henture existned for yeing find out which over afted together. natire roiction..
# thostery, of the ; imagint else possessers and extimate alt with self is do contomitury he gen
# indisidue romen--formy that
# a give
# Epoch 18/20
# 200285/200285 [==============================] - 150s 747us/step - loss: 1.0287
#
# ----- Generating text after Epoch: 17
# ----- diversity: 0.2
# ----- Generating with seed: "hat results may now be very clearly perc"
# hat results may now be very clearly perceived that the constant for the existect of the skepticion of the methost the soul of superstitions of the subject of allegyty--they are not be the feelings that there are the subject of allegyty--they are not be the experience that the substator and scholars of a child and as it is not the one of the most responsible for inseaniage of the same misuntious degreation; it such is always we makes the
# ----- diversity: 0.5
# ----- Generating with seed: "hat results may now be very clearly perc"
# hat results may now be very clearly perceduined to do who are reso that there is an allows to the act of an end, in the generably believe in the historical and the sympathess which of a
# southing the spiritual ends act of the masterous spirit of a simple, and in the same of charming and finss of consciences and the character of the patiest at present itself in some on the world, strength, lakes of althory instrumen to the moral of all re
# ----- diversity: 1.0
# ----- Generating with seed: "hat results may now be very clearly perc"
# hat results may now be very clearly perceived and arr"quethern
# vained a
# massher benour is aniover attaposion is goodness, do what? leasts a defice, but an ernitivining himself:
# he whose
# from outerfulualy celeat otherststed to meann-shally
# not who has ye re sich, ones. chremchee sensitien..
#
# he ever
# ulfuxitsy distracte blow that a my opinion is
# else in a "hasty, the eorly men, and and whole very hearly seleas it is something among their
# ----- diversity: 1.2
# ----- Generating with seed: "hat results may now be very clearly perc"
# hat results may now be very clearly perceamed to surman?"gay,
# detenseh, clases--so that the apparenticaval mank
# ider of sothing-will to the disinte well
# knicele knowledge
# proporines
# in especial to good--what a generally
# bloss in their laws, gradation, a thistorities with hemism and
# hanthratirate
# lovince belong
# exception",, and the nobilies, as an
# conscionce is us, let up an
# and instruauces wears and evid
# and circulsess.; areby to replis
# Epoch 19/20
# 200285/200285 [==============================] - 149s 742us/step - loss: 1.0281
#
# ----- Generating text after Epoch: 18
# ----- diversity: 0.2
# ----- Generating with seed: "ns whereby the european spirit has
# attai"
# ns whereby the european spirit has
# attained the discovering of very anything to the moral of all reasons, is the subject of a their extent of a sidged with a philosopher, and and in the senses of the world, and the same with some protection, and so that a plice of the sensable
# and strength and existle of greates, an errors on the contraster happined in the standific eving of the word of man, who has been some comparien of the entire and
# ----- diversity: 0.5
# ----- Generating with seed: "ns whereby the european spirit has
# attai"
# ns whereby the european spirit has
# attained states of the conception of the world is senseal to a soul of the objeined forc? beformerned man, approcistian doem to the among and self-destructions of the act of such depermined and despare ideal of all reacong whech are not one is the ancient is it belief individual and
# explanation is exceptions, and consequence by thind and the suns and the state of a condition of the end without of the p
# ----- diversity: 1.0
# ----- Generating with seed: "ns whereby the european spirit has
# attai"
# ns whereby the european spirit has
# attained -"                          isex thied ever not se, wemnatht contry mecroadity,
# he is not be
# cruelty of
# strange, and not rathodse and eals and kiold being. . : ; s mus immopst
# conserved nothing on the world effement
# in the diseing the stacture of human
# in fillests and consexcess in such sacrifice,
# the edecien and made of an impormation on the really germans which
# happent to a nour feels its ei
# ----- diversity: 1.2
# ----- Generating with seed: "ns whereby the european spirit has
# attai"
# ns whereby the european spirit has
# attained name of stangness
# and
# creativally. where--they
# the art of happining hams?
#
#
# 1mogaite. still love in it.
# sharmanian philosophigy, the
# explosed
# trawist redig, instircled to
# us, and
# taken and for-stimnses. lox--thatreplen bruad
# im, gefectre craves!--artislic, gered
# bal, in ecovoly tyon, which
# magatly be agos himself you ortan book, should
# laudds do whater, cleinged
# "heprets"
# very ather is be othe
# Epoch 20/20
# 200285/200285 [==============================] - 148s 741us/step - loss: 1.0283
#
# ----- Generating text after Epoch: 19
# ----- diversity: 0.2
# ----- Generating with seed: "ents and marvelous experiences when a gr"
# ents and marvelous experiences when a great during to the intention is not a decent, and a be and the subject of a surgain and interpret and soul of self iscenment to and accouders and exceptional strong and interpret and inclination of the subcesesured. the truth of mankind, which is commanly contramunting of a certain attempt to the things which religion of the world of all the sensable notions and interpret an and such a state of a h
# ----- diversity: 0.5
# ----- Generating with seed: "ents and marvelous experiences when a gr"
# ents and marvelous experiences when a great duty the delight of the soul of superstition the procected menness, and in the majority and
# the state of protrem that is the basis of one's own strie. the self and person of children originated. the same of religious certainty we act and consequently and the love of religions and despart sciences of the sensable
# ampsouday: "
# he who mather soke in the soul of man confluments hell every pleason
# ----- diversity: 1.0
# ----- Generating with seed: "ents and marvelous experiences when a gr"
# ents and marvelous experiences when a greater nation, ignous buty in
# catem of whome, to scervalist
# undurstant exercised to enjoy their feeling, than seem lighten?
# the more sufferion of psocleding--and naturaterism, far
# innxience of longing, hithert been with his found.ten
# often is, every powerf abure the dogrataring uncertain, an setions have been, simply loke which learn admirack and what is
# more
# "goinessh; with it. should be any above
# ----- diversity: 1.2
# ----- Generating with seed: "ents and marvelous experiences when a gr"
# ents and marvelous experiences when a great disedvended him set of elreopociet, "
# will: what so trou-said to the awy we perrifities, still, loves principle, and there
# is not times with actist. but that she such ally, understant,
# bur
# emnticmly siske, will neity--this his looking of mainifuloges, of great philosopher, the procured man esything.its as humart about gnoug?
# the will of madrerm to favour, cuseces uner? affains philosoppocas of

# %% [markdown]
# Investigation ends here.
