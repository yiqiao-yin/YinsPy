# %% [markdown]
# # YIN'S MONEY MANAGEMENT (YinsMM): Starter Code Initiation
#
# This notebook loads a script and runs through starting code to investigate company profile.

# %% [markdown]
# ### Load Library: YinsMM

# %%
# %run "../scripts/YinsMM.py"
# Out:
# -----------------------------------------------------
#
#         Yin's Money Managment Package
#         Copyright © YINS CAPITAL, 2009 – Present
#         For more information, please go to www.YinsCapital.com
#
# -----------------------------------------------------

# %% [markdown]
# ### Execute Code

# %%
# RUN
# Input (stock info, date frame, figure size, lower/upper bound, list of verbose)
# Output (function creates a dictionary of data):
temp = YinsMM.YinsInvestigator(
    start_date='2010-01-01', end_date='2020-01-18', 
    ticker='BA', figsize=(8, 4), LB=-0.05, UB=0.09, pastNdays=10,
    plotGraph=True, verbose=True, printManual=False, printSummary=True, gotoSEC=True, showInteractive=True)
# Out:
# [*********************100%***********************]  1 of 1 completed
# ----------------------------------------------------------------------------------------------------
# Entered Stock has the following information:
# Ticker: BA
# ---
# ...

# %%
temp['InterPlot']['chart']
# Out:
# :NdOverlay   [Variable]
#    :Curve   [Date]   (value)

# %%
temp['InterPlot']['signal']
# Out:
# :NdOverlay   [Variable]
#    :Curve   [Date]   (value)

# %%
temp['InterPlot']['paraPlot']

# %% [markdown]
# Investiation ends here.
